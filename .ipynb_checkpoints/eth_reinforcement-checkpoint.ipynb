# %% [markdown]
# # Reinforcement Learning with ETH/USD Data

# %%
# Gym stuff
import gym
import gym_anytrading
from gym_anytrading.envs import TradingEnv, ForexEnv, ForexEnv, Actions, Positions 

#rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sqlite3

# %%
database = sqlite3.connect("eth_usd_one_day_all_inds.sqlite")
df = pd.read_sql_query("SELECT * FROM prices", database)

df
# Out:
#         id     name                 date         high          low  \
# 0        1  ETH-USD  2017-11-09 00:00:00   329.451996   307.056000
# 1        2  ETH-USD  2017-11-10 00:00:00   324.717987   294.541992
# 2        3  ETH-USD  2017-11-11 00:00:00   319.453003   298.191986
# 3        4  ETH-USD  2017-11-12 00:00:00   319.153015   298.513000
# 4        5  ETH-USD  2017-11-13 00:00:00   328.415009   307.024994
# ...    ...      ...                  ...          ...          ...
# 1712  1713  ETH-USD  2022-07-18 00:00:00  1578.717896  1338.806030
# 1713  1714  ETH-USD  2022-07-19 00:00:00  1607.033081  1501.797485
# 1714  1715  ETH-USD  2022-07-20 00:00:00  1612.645752  1500.803223
# 1715  1716  ETH-USD  2022-07-21 00:00:00  1595.761963  1472.185425
# 1716  1717  ETH-USD  2022-07-22 00:00:00  1595.750610  1560.727051
#
#             close  high_perc   low_perc  price_chg      massi        mfi  \
# 0      320.884003  -2.670122   4.309346        NaN        NaN        NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['date'])
df.drop(['date'], axis=1, inplace=True)
df.dtypes
# Out:
# id                    int64
# name                 object
# high                float64
# low                 float64
# close               float64
# high_perc           float64
# low_perc            float64
# price_chg           float64
# massi               float64
# mfi                 float64
# adx                 float64
# dmp                 float64
# dmn                 float64
# rsi                 float64
# slowd               float64
# slowk               float64
# target              float64
# Date         datetime64[ns]
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'high', 'low', 'close', 'high_perc', 'low_perc',
#        'price_chg', 'massi', 'mfi', 'adx', 'dmp', 'dmn', 'rsi', 'slowd',
#        'slowk', 'target', 'Date'],
#       dtype='object')

# %%
df.drop([ "id", "name", "target" ], axis=1, inplace=True)
df.dropna(inplace=True)
df.set_index('Date', inplace=True)
df['Close'] = df['close']
df.drop([ "close" ], axis=1, inplace=True)
df
# Out:
#                    high          low  high_perc   low_perc  price_chg  \
# Date
# 2017-12-11   516.968994   439.104004  -0.355830  14.759594   4.163843
# 2017-12-12   657.317993   504.493988  -0.903697  22.556040  -0.666957
# 2017-12-13   747.992981   597.797974  -6.435412  14.936537   0.516041
# 2017-12-14   753.120972   664.989014  -8.235653   4.430333   0.925346
# 2017-12-15   697.132019   621.060974  -1.853175   9.261043  -1.494342
# ...                 ...          ...        ...        ...        ...
# 2022-07-17  1378.417480  1329.763306  -2.971812   0.662797   4.090147
# 2022-07-18  1578.717896  1338.806030   0.000000  15.196627  -1.234117
# 2022-07-19  1607.033081  1501.797485  -4.151581   2.668723  -0.454236
# 2022-07-20  1612.645752  1500.803223  -6.081110   1.275980  -4.157531
# 2022-07-21  1595.761963  1472.185425  -1.205800   6.631623  -6.485843
#
#                 massi        mfi        adx        dmp        dmn        rsi  \
# Date
# ...

# %%
df = df.iloc[::-1]
df
# Out:
#                    high          low  high_perc   low_perc  price_chg  \
# Date
# 2022-07-21  1595.761963  1472.185425  -1.205800   6.631623  -6.485843
# 2022-07-20  1612.645752  1500.803223  -6.081110   1.275980  -4.157531
# 2022-07-19  1607.033081  1501.797485  -4.151581   2.668723  -0.454236
# 2022-07-18  1578.717896  1338.806030   0.000000  15.196627  -1.234117
# 2022-07-17  1378.417480  1329.763306  -2.971812   0.662797   4.090147
# ...                 ...          ...        ...        ...        ...
# 2017-12-15   697.132019   621.060974  -1.853175   9.261043  -1.494342
# 2017-12-14   753.120972   664.989014  -8.235653   4.430333   0.925346
# 2017-12-13   747.992981   597.797974  -6.435412  14.936537   0.516041
# 2017-12-12   657.317993   504.493988  -0.903697  22.556040  -0.666957
# 2017-12-11   516.968994   439.104004  -0.355830  14.759594   4.163843
#
#                 massi        mfi        adx        dmp        dmn        rsi  \
# Date
# ...

# %%
def my_process_data(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Close', 'high', 'low']].to_numpy()[start:end]
    return prices, signal_features

#['Close', 'high_perc', 'low_perc', 'price_chg', 'massi', 'mfi', 'adx', 'dmp', 'dmn', 'rsi', 'slowd', 'slowk']


class MyForexEnv(ForexEnv):
    _process_data = my_process_data


env = MyForexEnv(df=df, window_size=5, frame_bound=(5, 100))

# %%
env.signal_features
# Out:
# array([[1576.74951172, 1595.76196289, 1472.1854248 ],
#        [1520.20068359, 1612.64575195, 1500.80322266],
#        [1542.97521973, 1607.03308105, 1501.79748535],
#        [1578.71789551, 1578.71789551, 1338.80603027],
#        [1338.63574219, 1378.41748047, 1329.76330566],
#        [1352.62646484, 1377.94458008, 1195.60595703],
#        [1233.12915039, 1275.77819824, 1182.90319824],
#        [1191.52624512, 1202.95336914, 1077.40576172],
#        [1113.5871582 , 1113.5871582 , 1019.22033691],
#        [1038.19165039, 1097.25915527, 1038.13562012],
#        [1097.23657227, 1169.19384766, 1095.00280762],
#        [1168.40161133, 1216.90441895, 1157.17553711],
#        [1216.97827148, 1228.76794434, 1209.37756348],
#        [1222.50622559, 1262.88574219, 1200.63220215],
#        [1237.59338379, 1246.89489746, 1165.62316895],
#        [1186.97399902, 1193.63671875, 1116.24755859],
#        [1134.54101562, 1165.68273926, 1086.82995605],
# ...

# %%
state = env.reset()
while True:
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 8260791.015625, 'total_profit': 0.8972411034629202, 'position': 0}

# %%
#env_maker = lambda: MyForexEnv(df=df, window_size=5, frame_bound=(5, 100))
from stable_baselines3.common.monitor import Monitor

env = DummyVecEnv([lambda: Monitor(MyForexEnv(df=df, window_size=5, frame_bound=(5, 100)))])

# %%
df.dtypes
# Out:
# high         float64
# low          float64
# high_perc    float64
# low_perc     float64
# price_chg    float64
# massi        float64
# mfi          float64
# adx          float64
# dmp          float64
# dmn          float64
# rsi          float64
# slowd        float64
# slowk        float64
# Close        float64
# dtype: object

# %%
from sb3_contrib.ppo_recurrent.policies import MlpLstmPolicy
from sb3_contrib.ppo_recurrent.ppo_recurrent import RecurrentPPO
from stable_baselines3.common.callbacks import EvalCallback

eval_callback = EvalCallback(env, best_model_save_path='./logs/',
                             log_path='./logs/', eval_freq=10000,
                             deterministic=True, render=False)


model = RecurrentPPO("MlpLstmPolicy", env, verbose=1)
model.learn(total_timesteps=100000, callback=eval_callback)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94       |
# |    ep_rew_mean     | 4.65e+06 |
# | time/              |          |
# |    fps             | 889      |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 128      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | -4.81e+06   |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 1.44355e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# ...

# %%
model = RecurrentPPO.load('./logs/best_model.zip')

# %%
env = MyForexEnv(df=df, window_size=5, frame_bound=(100, 150))
obs = env.reset()
while True:
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -6795190.4296875, 'total_profit': 0.9356719677104642, 'position': 1}
